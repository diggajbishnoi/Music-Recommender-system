# %% [markdown]
# <a href="https://colab.research.google.com/github/diggajbishnoi/Music-Recommender-system/blob/main/Music_Recommender_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### **Loading the dataset**:-

# %%
url='https://raw.githubusercontent.com/diggajbishnoi/Music-Recommender-system/main/spotify_millsongdata.csv'
df = pd.read_csv(url)
df
# Out:
#              artist                   song  \
# 0              ABBA  Ahe's My Kind Of Girl
# 1              ABBA       Andante, Andante
# 2              ABBA         As Good As New
# 3              ABBA                   Bang
# 4              ABBA       Bang-A-Boomerang
# ...             ...                    ...
# 57645  Ziggy Marley          Good Old Days
# 57646  Ziggy Marley          Hand To Mouth
# 57647          Zwan           Come With Me
# 57648          Zwan                 Desire
# 57649          Zwan              Heartsong
#
#                                               link  \
# 0       /a/abba/ahes+my+kind+of+girl_20598417.html
# 1            /a/abba/andante+andante_20002708.html
# 2             /a/abba/as+good+as+new_20003033.html
# 3                       /a/abba/bang_20598415.html
# 4           /a/abba/bang+a+boomerang_20002668.html
# ...                                            ...
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# ...

# %%
df.head(5)
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \r\nA...
# 1  Take it easy with me, please  \r\nTouch me gen...
# 2  I'll never know why I had to go  \r\nWhy I had...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %%
df.tail(5)
# Out:
#              artist           song  \
# 57645  Ziggy Marley  Good Old Days
# 57646  Ziggy Marley  Hand To Mouth
# 57647          Zwan   Come With Me
# 57648          Zwan         Desire
# 57649          Zwan      Heartsong
#
#                                               link  \
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# 57646  /z/ziggy+marley/hand+to+mouth_20531167.html
# 57647           /z/zwan/come+with+me_20148981.html
# 57648                 /z/zwan/desire_20148986.html
# 57649              /z/zwan/heartsong_20148991.html
#
#                                                     text
# 57645  Irie days come on play  \r\nLet the angels fly...
# 57646  Power to the workers  \r\nMore power  \r\nPowe...
# 57647  all you need  \r\nis something i'll believe  \...
# 57648  northern star  \r\nam i frightened  \r\nwhere ...
# 57649  come in  \r\nmake yourself at home  \r\ni'm a ...

# %%
## Shape of the dataset:-

df.shape
# Out:
# (57650, 4)

# %%
## check null values: -

df.isnull().sum()
# Out:
# artist    0
# song      0
# link      0
# text      0
# dtype: int64

# %%
df.isna().sum()
# Out:
# artist    0
# song      0
# link      0
# text      0
# dtype: int64

# %%
## droping the 'link' colmn:-

df =df.sample(5000).drop('link', axis=1).reset_index(drop=True)
df
# Out:
#                 artist                        song  \
# 0          Chris Brown                      Liquor
# 1      Michael Jackson                         Cry
# 2      Religious Music  Go Tell It On The Mountain
# 3          Xavier Rudd                    Stargaze
# 4                  Sia               Bird Set Free
# ...                ...                         ...
# 4995             Judds         Come Some Rainy Day
# 4996  Widespread Panic                       Waker
# 4997          Coldplay                    Midnight
# 4998    Billie Holiday                   All Of Me
# 4999    Jennifer Lopez                  Loving You
#
#                                                    text
# 0     [Verse 1]  \r\nThere's something in this liquo...
# 1     Somebody shakes when the wind blows  \r\nSomeb...
# 2     Go, tell it on the mountain  \r\nOver the hill...
# 3     Stargaze, I feel it with everything you do  \r...
# 4     [Verse 1]  \r\nClipped wings, I was a broken t...
# ...

# %%
df.head(10)
# Out:
#                artist                          song  \
# 0         Chris Brown                        Liquor
# 1     Michael Jackson                           Cry
# 2     Religious Music    Go Tell It On The Mountain
# 3         Xavier Rudd                      Stargaze
# 4                 Sia                 Bird Set Free
# 5          Quiet Riot                Don't Think So
# 6                 Rem               Redhead Walking
# 7         The Beatles                    For No One
# 8  Dave Matthews Band  Long Black Veil (Johny Cash)
# 9       Alison Krauss             My Poor Old Heart
#
#                                                 text
# 0  [Verse 1]  \r\nThere's something in this liquo...
# 1  Somebody shakes when the wind blows  \r\nSomeb...
# 2  Go, tell it on the mountain  \r\nOver the hill...
# 3  Stargaze, I feel it with everything you do  \r...
# 4  [Verse 1]  \r\nClipped wings, I was a broken t...
# 5  [Verse 1:]  \r\nYou sucked religion from my li...
# ...

# %%
## viewing the complete first song :-

df['text'][0]
# Out:
# "[Verse 1]  \r\nThere's something in this liquor, the air is getting thicker  \r\nI can't help but to stare at you, oh yeah, girl what did you do to me?  \r\nWhat did you slip up in my cup, girl? Cause I want you, oh yeah  \r\nI had a little bit too much girl, so come over here  \r\n  \r\n[Chorus]  \r\nThere's something in this liquor, oh yeah  \r\nThe air is getting thicker  \r\nAll I want is you-ou-ou-ou  \r\nAll I want is you-ou-ou-ou  \r\n  \r\n[Verse 2]  \r\nThere's something in this liquor girl, I'm looking at your figure woah  \r\nI just want to see you strip right now, baby let me help you work it out, oh  \r\nGirl you look so good, I just wanna get right to it, oh  \r\nI could beat it up like-like a real nigga should, baby when we do it, woah  \r\n  \r\n[Chorus]  \r\nThere's something in this liquor, oh yeah  \r\nThe air is getting thicker  \r\nAll I want is you-ou-ou-ou  \r\nAll I want is you-ou-ou-ou  \r\n  \r\n[Post-Chorus]  \r\nAll I wanna do is drink and fuck, drink, dr
# ...

# %%
# df = df.sample(5000)

# %%
df.shape
# Out:
# (5000, 3)

# %% [markdown]
# ### **Text Preprocessing:-**

# %%
df['text'] = df['text'].str.lower().replace(r'^\w\s',' ').replace(r'\n',' ',regex = True)

# %%
df
# Out:
#                 artist                        song  \
# 0          Chris Brown                      Liquor
# 1      Michael Jackson                         Cry
# 2      Religious Music  Go Tell It On The Mountain
# 3          Xavier Rudd                    Stargaze
# 4                  Sia               Bird Set Free
# ...                ...                         ...
# 4995             Judds         Come Some Rainy Day
# 4996  Widespread Panic                       Waker
# 4997          Coldplay                    Midnight
# 4998    Billie Holiday                   All Of Me
# 4999    Jennifer Lopez                  Loving You
#
#                                                    text
# 0     [verse 1]  \r there's something in this liquor...
# 1     somebody shakes when the wind blows  \r somebo...
# 2     go, tell it on the mountain  \r over the hills...
# 3     stargaze, i feel it with everything you do  \r...
# 4     [verse 1]  \r clipped wings, i was a broken th...
# ...

# %%
df.head(5)
# Out:
#             artist                        song  \
# 0      Chris Brown                      Liquor
# 1  Michael Jackson                         Cry
# 2  Religious Music  Go Tell It On The Mountain
# 3      Xavier Rudd                    Stargaze
# 4              Sia               Bird Set Free
#
#                                                 text
# 0  [verse 1]  \r there's something in this liquor...
# 1  somebody shakes when the wind blows  \r somebo...
# 2  go, tell it on the mountain  \r over the hills...
# 3  stargaze, i feel it with everything you do  \r...
# 4  [verse 1]  \r clipped wings, i was a broken th...

# %%
df.tail(5)
# Out:
#                 artist                 song  \
# 4995             Judds  Come Some Rainy Day
# 4996  Widespread Panic                Waker
# 4997          Coldplay             Midnight
# 4998    Billie Holiday            All Of Me
# 4999    Jennifer Lopez           Loving You
#
#                                                    text
# 4995  what good's a dollar  \r without your baby sis...
# 4996  my name is the waker  \r and i'm bringin' you ...
# 4997  in the darkness before the dawn  \r in the swi...
# 4998  you took my kisses and all my love  \r you tau...
# 4999  would you mind  \r if i took the time to get t...

# %%
import nltk
from nltk.stem.porter import PorterStemmer

# %%
stemmer = PorterStemmer()

# %%
def token(txt):
  token = nltk.word_tokenize(txt)
  a = [stemmer.stem(w) for w in token]
  return " ". join(a)

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
token('you are beautiful,beauty')
# Out:
# 'you are beauti , beauti'

# %%
df['text'].apply(lambda x: token(x))
# Out:
# 0       [ vers 1 ] there 's someth in thi liquor , the...
# 1       somebodi shake when the wind blow somebodi 's ...
# 2       go , tell it on the mountain over the hill and...
# 3       stargaz , i feel it with everyth you do and i ...
# 4       [ vers 1 ] clip wing , i wa a broken thing had...
#                               ...
# 4995    what good 's a dollar without your babi sister...
# 4996    my name is the waker and i 'm bringin ' you th...
# 4997    in the dark befor the dawn in the swirl of thi...
# 4998    you took my kiss and all my love you taught me...
# 4999    would you mind if i took the time to get to kn...
# Name: text, Length: 5000, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
tfid = TfidfVectorizer(analyzer = 'word',stop_words='english')

# %%
matrix = tfid.fit_transform(df['text'])

# %%
similar = cosine_similarity(matrix)

# %%
similar[0]
# Out:
# array([1.        , 0.01459258, 0.00407816, ..., 0.        , 0.01226408,
#        0.02837857])

# %%
'All Of Me' in df['song'].values
# Out:
# True

# %%
df[df['song'] == 'All Of Me'].index[0]
# Out:
# 826

# %% [markdown]
# ## **Recommender function**:-

# %%
def recommender(song_name):
  idx = df[df['song'] == song_name].index[0]
  distance = sorted(list(enumerate(similar[idx])),reverse=True , key = lambda x:x[1])
  song = []
  for s_id in distance[1:21]:
    song.append(df.iloc[s_id[0]].song)
  return song

# %%
recommender('Come Some Rainy Day')
# Out:
# ['Here Comes That Rainy Day Feeling Again',
#  'Have You Ever Needed Someone So Bad',
#  'Promise',
#  'Our Time Is Here',
#  'Completely',
#  'Half A Woman, Half A Shadow',
#  "Say You'll Never Go",
#  'Stay Or Leave',
#  'If You Go Away',
#  'All The Way',
#  'Ice Cream Man',
#  'Cosmic',
#  'Never Wanted Nothing More',
#  'Dreaming My Dreams With You',
#  'Feel So Bad',
#  'Miles Apart',
#  'Love Is Just A Breath Away',
#  'We Could Have Been',
#  'One More Day',
#  "I'll Never Love This Way Again"]

# %%
import pickle

# %%
pickle.dump(similar,open("similarity","wb"))

# %%
pickle.dump(df,open("df","wb"))
